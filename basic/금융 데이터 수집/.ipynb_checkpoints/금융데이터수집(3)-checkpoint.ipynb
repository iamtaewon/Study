# %% [markdown]
# # FRED 경제데이터 가져오기
#
# ## FRED : Federal Reserve Economic Data
# #### https://en.wikipedia.org/wiki/Federal_Reserve_Economic_Data
# ### https://fred.stlouisfed.org
# ## https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %%
# FRED(Federal Reserve Economic Data) 세인트루이스 연준 관리 경제통계 데이터베이스
# 각 항목별 티커를 찾는 방법
# FRED 웹사이트(https://fred.stlouisfed.org/) 에서 원하는 데이터를 검색
# /series/ 다음에 위치하는 DEXKOUS가 해당 항목의 티커

# %% [markdown]
# ## 미국 GDP

# %%
# 미국 GDP

import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '2000-01-01')
data1.head()
# Out:
#                   GDP
# DATE
# 2000-01-01  10002.179
# 2000-04-01  10247.720
# 2000-07-01  10318.165
# 2000-10-01  10435.744
# 2001-01-01  10470.231

# %%
import pandas_datareader as pdr

data2 = pdr.DataReader('T10Y2Y', 'fred', '2000-01-01')
data2.tail(5)
# Out:
#             T10Y2Y
# DATE
# 2023-03-21   -0.58
# 2023-03-22   -0.48
# 2023-03-23   -0.38
# 2023-03-24   -0.38
# 2023-03-27   -0.41

# %%
import matplotlib.pyplot as plt
data2.plot(figsize=(10,6))
plt.show()

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2022, 6, 27)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2020-01-01 to 2022-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     10 non-null     float64
# dtypes: float64(1)
# memory usage: 160.0 bytes

# %%
gdp
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476

# %%
gdp.tail(10)
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476

# %%
# GDP 기초통계량
gdp.describe()
# Out:
#                 GDP
# count     10.000000
# mean   22749.117800
# std     1759.417449
# min    19636.731000
# 25%    21579.700500
# 50%    22680.392000
# 75%    24149.445750
# max    25248.476000

# %%
gdp.loc['2022-01-01']
# Out:
# GDP    24740.48
# Name: 2022-01-01 00:00:00, dtype: float64

# %% [markdown]
# ## 인플레이션

# %%
# 인플레이션
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)
inflation
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2020-01-01   259.037   266.626
# 2020-02-01   259.248   267.283
# 2020-03-01   258.124   267.090
# 2020-04-01   256.092   265.771
# 2020-05-01   255.868   265.574
# 2020-06-01   256.986   265.952
# 2020-07-01   258.278   267.352
# 2020-08-01   259.411   268.469
# 2020-09-01   260.029   268.938
# 2020-10-01   260.286   269.236
# 2020-11-01   260.813   269.901
# 2020-12-01   262.035   270.267
# 2021-01-01   262.650   270.383
# 2021-02-01   263.638   270.727
# 2021-03-01   264.914   271.526
# 2021-04-01   266.670   273.615
# 2021-05-01   268.444   275.654
# 2021-06-01   270.559   277.676
# 2021-07-01   271.764   278.522
# 2021-08-01   272.870   279.057
# 2021-09-01   274.028   279.755
# 2021-10-01   276.522   281.588
# 2021-11-01   278.711   283.340
# 2021-12-01   280.887   285.193
# 2022-01-01   282.599   286.792
# 2022-02-01   284.610   288.147
# 2022-03-01   287.472   289.046
# 2022-04-01   288.611   290.410
# 2022-05-01   291.268   292.251
# 2022-06-01   294.728   294.017

# %%
from pandas_datareader import wb
matches = wb.search('gdp.*capita.*const')
matches
# Out:
#                          id  \
# 691      6.0.GDPpc_constant
# 10629        NY.GDP.PCAP.KD
# 10631        NY.GDP.PCAP.KN
# 10633     NY.GDP.PCAP.PP.KD
# 10634  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 691    GDP per capita, PPP (constant 2011 internation...
# 10629                 GDP per capita (constant 2015 US$)
# 10631                      GDP per capita (constant LCU)
# 10633  GDP per capita, PPP (constant 2017 internation...
# 10634  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 691                  LAC Equity Lab
# 10629  World Development Indicators
# 10631  World Development Indicators
# 10633  World Development Indicators
# 10634         WDI Database Archives
#
#                                               sourceNote  \
# 691    GDP per capita based on purchasing power parit...
# 10629  GDP per capita is gross domestic product divid...
# 10631  GDP per capita is gross domestic product divid...
# 10633  GDP per capita based on purchasing power parit...
# 10634
#
#                                       sourceOrganization            topics
# 691         b'World Development Indicators (World Bank)'  Economy & Growth
# 10629  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10631  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10633  b'International Comparison Program, World Bank...  Economy & Growth
# 10634                                                b''

# %%
import requests
import json
data = requests.get('https://api.stlouisfed.org/fred/series?series_id=GNPCA&api_key=43be4fc471782325cab7d47238bf8962&file_type=json')

# %%
data.json()
# Out:
# {'realtime_start': '2023-03-28',
#  'realtime_end': '2023-03-28',
#  'seriess': [{'id': 'GNPCA',
#    'realtime_start': '2023-03-28',
#    'realtime_end': '2023-03-28',
#    'title': 'Real Gross National Product',
#    'observation_start': '1929-01-01',
#    'observation_end': '2021-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Chained 2012 Dollars',
#    'units_short': 'Bil. of Chn. 2012 $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2022-09-29 07:45:54-05',
#    'popularity': 15,
#    'notes': 'BEA Account Code: A001RX\n\n'}]}

# %%
# datapungi_fed 설치 필요
# !pip install datapungi_fed
# Out:
# Collecting datapungi_fed
#   Downloading datapungi_fed-0.3.1-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.1/101.1 kB 6.8 MB/s eta 0:00:00
# Collecting pytest-html
#   Downloading pytest_html-3.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (4.11.1)
# Requirement already satisfied: xlrd in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (2.0.1)
# Requirement already satisfied: pyyaml in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (6.0)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (1.4.4)
# Requirement already satisfied: pytest in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (7.1.2)
# Requirement already satisfied: lxml in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (4.9.1)
# Requirement already satisfied: html5lib in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (1.1)
# Requirement already satisfied: requests in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from datapungi_fed) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->datapungi_fed) (2.3.1)
# Requirement already satisfied: webencodings in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from html5lib->datapungi_fed) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from html5lib->datapungi_fed) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->datapungi_fed) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->datapungi_fed) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->datapungi_fed) (1.21.5)
# Requirement already satisfied: attrs>=19.2.0 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (21.4.0)
# Requirement already satisfied: iniconfig in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (1.1.1)
# Requirement already satisfied: packaging in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pytest->datapungi_fed) (2.0.1)
# Collecting pytest-metadata
#   Downloading pytest_metadata-2.0.4-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from requests->datapungi_fed) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from requests->datapungi_fed) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from requests->datapungi_fed) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from requests->datapungi_fed) (1.26.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from packaging->pytest->datapungi_fed) (3.0.9)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11123 sha256=a6436d7d51ff81932714bd2a391c08a331dc679eef447d811dc868ee47cfb6f7
#   Stored in directory: /Users/taewon/Library/Caches/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pyperclip, pytest-metadata, pytest-html, datapungi_fed
# Successfully installed datapungi_fed-0.3.1 pyperclip-1.8.2 pytest-html-3.2.0 pytest-metadata-2.0.4

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.9.13, pytest-7.1.2, pluggy-1.0.0
# rootdir: /Users/taewon/금융 데이터 수집
# plugins: anyio-3.5.0, html-3.2.0, metadata-2.0.4
# collected 0 items
#
# ============================ no tests ran in 0.00s =============================

# %% [markdown]
# ## FRED에서 API 경제데이터 가져오기

# %%
# 설치하기
# !pip install fredapi
# Out:
# Requirement already satisfied: fredapi in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: pandas in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from fredapi) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->fredapi) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from pandas->fredapi) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/taewon/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->fredapi) (1.16.0)

# %%
from fredapi import Fred
fred = Fred(api_key='facfa1b1647b470aa1ab6d747bb53a16')
data = fred.get_series('GDP')

# %%
data = fred.get_series_first_release('GDP')
data.tail(10)
# Out:
# date
# 2020-07-01    21157.635
# 2020-10-01    21479.529
# 2021-01-01    22048.894
# 2021-04-01    22722.581
# 2021-07-01    23173.496
# 2021-10-01    23992.355
# 2022-01-01    24382.683
# 2022-04-01    24851.809
# 2022-07-01    25663.289
# 2022-10-01    26132.458
# Name: value, dtype: object

# %%
data = fred.get_series_latest_release('GDP')
data
# Out:
# 1946-01-01          NaN
# 1946-04-01          NaN
# 1946-07-01          NaN
# 1946-10-01          NaN
# 1947-01-01      243.164
#                 ...
# 2021-10-01    24349.121
# 2022-01-01    24740.480
# 2022-04-01    25248.476
# 2022-07-01    25723.941
# 2022-10-01    26144.956
# Length: 308, dtype: float64

# %%
fred.get_series_as_of_date('GDP', '6/1/2019')
# Out:
#      realtime_start       date      value
# 0        1992-12-22 1946-01-01      199.7
# 1        1996-01-19 1946-01-01        NaT
# 2        1997-05-07 1946-01-01      210.4
# 3        1999-10-28 1946-01-01        NaT
# 4        1992-12-22 1946-04-01      207.7
# ...             ...        ...        ...
# 3017     2018-12-21 2018-07-01  20658.204
# 3022     2019-02-28 2018-10-01  20891.367
# 3023     2019-03-28 2018-10-01   20865.14
# 3028     2019-04-26 2019-01-01  21062.691
# 3029     2019-05-30 2019-01-01  21048.839
#
# [2906 rows x 3 columns]

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2018-04-01  2.87
# 2018-05-01  2.98
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
# 2019-01-01  2.71
# 2019-02-01  2.68
# 2019-03-01  2.57
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# 2022-05-01  2.90
# 2022-06-01  3.14
# 2022-07-01  2.90
# 2022-08-01  2.90
# 2022-09-01  3.52
# 2022-10-01  3.98
# 2022-11-01  3.89
# 2022-12-01  3.62
# 2023-01-01  3.53
# 2023-02-01  3.75

# %%
# 날짜는 datetime 패키지를 사용하여 지정
# 또는 문자열을 바로 사용해도 된다. 

import pandas_datareader.data as web

import datetime

start = datetime.datetime(2010, 1, 1)

end = datetime.datetime(2022, 12, 31)

gdp = web.DataReader('GDP', 'fred', start, end)

gdp.loc['2022-01-01']
# Out:
# GDP    24740.48
# Name: 2022-01-01 00:00:00, dtype: float64

# %% [markdown]
# ### 데이터 코드에 리스트를 넣으면 여러개의 데이터를 동시에

# %%
# Multiple series:
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962
