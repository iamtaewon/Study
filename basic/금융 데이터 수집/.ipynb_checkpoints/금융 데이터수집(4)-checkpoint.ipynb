# %% [markdown]
# # 야후파이낸스에서 가져오기

# %%
# 설치하기
# !pip install yfinance

# %%
import yfinance as yf

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

sec=pdr.get_data_yahoo('005930.KS',start='2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sec.head()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2023-01-02  55500.0  56100.0  55200.0  55500.0    55500.0  10031448
# 2023-01-03  55400.0  56000.0  54500.0  55400.0    55400.0  13547030
# 2023-01-04  55700.0  58000.0  55600.0  57800.0    57800.0  20188071
# 2023-01-05  58200.0  58800.0  57600.0  58200.0    58200.0  15682826
# 2023-01-06  58300.0  59400.0  57900.0  59000.0    59000.0  17334989

# %%
msft=pdr.get_data_yahoo('AAPL', start='2019-04-11')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# 불러오기
import yfinance as yf

AAPL = yf.Ticker("AAPL")
print(AAPL)
# Out:
# yfinance.Ticker object <AAPL>

# %%
AAPL.info
# 왜 오류인지 모르겠음
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/28/yz261nq91vq_lj47hynw_10r0000gn/T/ipykernel_74562/518021954.py in <module>
# ----> 1 AAPL.info
#       2 # 왜 오류인지 모르겠음
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self) -> dict:
# --> 138         return self.get_info()
#     139
#     140     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/base.py in get_info(self, proxy)
#    1473     def get_info(self, proxy=None) -> dict:
#    1474         self._quote.proxy = proxy
# -> 1475         data = self._quote.info
#    1476         return data
#    1477
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/scrapers/quote.py in info(self)
#      93     def info(self) -> dict:
#      94         if self._info is None:
# ---> 95             self._scrape(self.proxy)
# ...

# %%
AAPL.head()

# %%
AAPL.history(period="max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099722    0.100155    0.099722    0.099722
# 1980-12-15 00:00:00-05:00    0.094953    0.094953    0.094519    0.094519
# 1980-12-16 00:00:00-05:00    0.088015    0.088015    0.087582    0.087582
# 1980-12-17 00:00:00-05:00    0.089749    0.090183    0.089749    0.089749
# 1980-12-18 00:00:00-05:00    0.092351    0.092785    0.092351    0.092351
# ...                               ...         ...         ...         ...
# 2023-03-22 00:00:00-04:00  159.300003  162.139999  157.809998  157.830002
# 2023-03-23 00:00:00-04:00  158.830002  161.550003  157.679993  158.929993
# 2023-03-24 00:00:00-04:00  158.860001  160.339996  157.850006  160.250000
# 2023-03-27 00:00:00-04:00  159.940002  160.770004  157.869995  158.279999
# 2023-03-28 00:00:00-04:00  157.970001  158.490005  155.979996  157.649994
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# 최근 1개월
AAPL.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-02-28 00:00:00-05:00  147.050003  149.080002  146.830002  147.410004
# 2023-03-01 00:00:00-05:00  146.830002  147.229996  145.009995  145.309998
# 2023-03-02 00:00:00-05:00  144.380005  146.710007  143.899994  145.910004
# 2023-03-03 00:00:00-05:00  148.039993  151.110001  147.330002  151.029999
# 2023-03-06 00:00:00-05:00  153.789993  156.300003  153.460007  153.830002
# 2023-03-07 00:00:00-05:00  153.699997  154.029999  151.130005  151.600006
# 2023-03-08 00:00:00-05:00  152.809998  153.470001  151.830002  152.869995
# 2023-03-09 00:00:00-05:00  153.559998  154.539993  150.229996  150.589996
# 2023-03-10 00:00:00-05:00  150.210007  150.940002  147.610001  148.500000
# 2023-03-13 00:00:00-04:00  147.809998  153.139999  147.699997  150.470001
# 2023-03-14 00:00:00-04:00  151.279999  153.399994  150.100006  152.589996
# 2023-03-15 00:00:00-04:00  151.190002  153.250000  149.919998  152.990005
# ...

# %%
AAPL.history(period="2022")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-03-28 00:00:00-04:00  157.970001  158.490005  155.979996  157.649994
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-03-28 00:00:00-04:00  45939800        0.0           0.0

# %%
# 여러 티커에 대한 데이터 가져오기
import yfinance as yf
data = yf.download("SPY AAPL", start="2022-01-01", end="2022-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2022-01-01", end="2022-06-30")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  476.299988  477.850006  473.850006  477.709991  468.296448
# 2022-01-04  479.220001  479.980011  475.579987  477.549988  468.139557
# 2022-01-05  477.160004  477.980011  468.279999  468.380005  459.150299
# 2022-01-06  467.890015  470.820007  465.429993  467.940002  458.718964
# 2022-01-07  467.950012  469.200012  464.649994  466.089996  456.905396
# ...                ...         ...         ...         ...         ...
# 2022-06-23  376.640015  378.829987  372.890015  378.059998  373.367340
# 2022-06-24  381.399994  390.089996  381.369995  390.079987  385.238129
# 2022-06-27  391.049988  391.359985  387.440002  388.589996  383.766632
# 2022-06-28  390.230011  393.160004  380.529999  380.649994  375.925171
# 2022-06-29  381.230011  382.269989  378.420013  380.339996  375.619019
#
#                Volume
# Date
# ...

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2021-12-31", end="2022-06-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# 구글링으로 찾아보기

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

sec=pdr.get_data_yahoo('005930.KS', start="2022-01-03")
AAPL=pdr.get_data_yahoo('AAPL', start="2022-01-03")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
sec.head()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2022-01-04  78800.0  79200.0  78300.0  78700.0  76808.179688  12427416
# 2022-01-05  78800.0  79000.0  76400.0  77400.0  75539.414062  25470640
# 2022-01-06  76700.0  77600.0  76600.0  76900.0  75051.437500  12931954
# 2022-01-07  78100.0  78400.0  77400.0  78300.0  76417.789062  15163757
# 2022-01-10  78100.0  78100.0  77100.0  78000.0  76124.992188   9947422

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글폰트 적용
from matplotlib import rc
rc('font', family='AppleGothic') # Mac Os
plt.rcParams['axes.unicode_minus'] = False

# plt.plot(range(50), data, 'r')
# plt.title('시간별 가격 추이', fontproperties=fontprop)
# plt.ylabel('주식 가격', fontproperties=fontprop)
# plt.xlabel('시간(분)', fontproperties=fontprop)
# plt.show()

plt.plot(sec.index, sec.Close, 'b', label='삼성전자')
plt.plot(AAPL.index, AAPL.Close, 'r--', label='APPLE')
plt.legend(loc='best')

# %%
# 불러온 데이터를 그대로 시각화한 결과 
# # 애플의 절대적인 수치가 상대적으로 너무 작기에 변동성이 구분되지 않아 직선으로 나타난다.

# 위와 같은 문제점을 해결하기 위해 shift 명령어를 활용하여 절대적인 주가 수준이 아닌 상승률로 값을 변환하여 비교해보자.

# %%
# shift?
type(sec['Close'])
sec['Close'].shift(1).head() # 데이터를 1만큼 lag
# Out:
# Date
# 2022-01-04        NaN
# 2022-01-05    78700.0
# 2022-01-06    77400.0
# 2022-01-07    76900.0
# 2022-01-10    78300.0
# Name: Close, dtype: float64

# %%
# shift 활용하여 수익률로 표현
sec_dpc_cs=(sec['Close']/sec['Close'].shift(1)-1)*100
sec_dpc_cs.head()

AAPL_dpc_cs = (AAPL['Close']/AAPL['Close'].shift(1)-1)*100
AAPL_dpc_cs.iloc[0] = 0

# %%
plt.plot(sec.index, sec_dpc_cs, 'b', label='삼성전자')
plt.plot(AAPL.index, AAPL_dpc_cs, 'r--', label='APPLE')
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pip install pyfolio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pyfolio

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import pyfolio as pf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/sklearn/__check_build/__init__.py in <module>
#      47 try:
# ---> 48     from ._check_build import check_build  # noqa
#      49 except ImportError as e:
#
# ...

# %%
RISKY_ASSETS = ['AAPL', 'IBM', 'MSFT', 'TWTR']
START_DATE = '2020-01-01'
END_DATE = '2021-12-31'

n_assets = len(RISKY_ASSETS)

# %%
prices_df = yf.download(RISKY_ASSETS, start=START_DATE, 
                        end=END_DATE, adjusted=True)
print(f'Downloaded {prices_df.shape[0]} rows of data.')
prices_df['Adj Close'].plot(title='Stock prices of the considered assets')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/28/yz261nq91vq_lj47hynw_10r0000gn/T/ipykernel_74562/1320140683.py in <module>
# ----> 1 prices_df = yf.download(RISKY_ASSETS, start=START_DATE,
#       2                         end=END_DATE, adjusted=True)
#       3 print(f'Downloaded {prices_df.shape[0]} rows of data.')
#       4 prices_df['Adj Close'].plot(title='Stock prices of the considered assets')
#
# TypeError: download() got an unexpected keyword argument 'adjusted'

# %%
# 오류 해결 필요
